# %%
import numpy as np
data = np.load("../data/03_data.npz")["data"]
data.shape
# Out:
# (52061, 375)

# %%
pose0 = np.load("../data/pose0.npy")
pose0.shape
# Out:
# (1, 375)

# %%
import sys
import os

sys.path.append(os.path.join(os.getcwd(), "motion-vae"))

import torch

cvae = torch.load("../weights/03-conditional-vae.pt", weights_only=False)
