# %%
import numpy as np

# %%
data = np.load("../data/03_data.npz")
X = data["data"].astype(np.float32)
end_indices = data["end_indices"]

# %%
end_indices.shape
# Out:
# (1093,)

# %%
X.shape
# Out:
# (1695894, 375)
